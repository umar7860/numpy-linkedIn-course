# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
X = np.random.randn(10000)
#it is 2D plot
plt.hist(X,bins = 20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
